# %%
import sys
sys.path.append('..')  

from src.database import setup_database, insert_reviews, verify_data

# %%
print("\n1. Setting up database...")
setup_database()
# Out:
# 1. Setting up database...
# ✅ 'bank_reviews' database already exists
# Database setup complete

# %%
#sys.path.append('..')
print("\n2. Inserting review data...")
inserted_count = insert_reviews()
# Out:
# 2. Inserting review data...
# ✅ Inserted 1200 reviews

# %%
print("\n3. Verifying data integrity...")
total_reviews = verify_data()
# Out:
# 3. Verifying data integrity...
#
# 📊 Total reviews: 1200
# Reviews per bank:
#   Dashen Bank: 400
#   Bank of Abyssinia: 400
#   Commercial Bank of Ethiopia: 400

# %%
print("REQUIREMENTS CHECK")

if total_reviews >= 400:
    print("SUCCESS: All requirements met!")
    print(f"   • Reviews inserted: {total_reviews} (≥400 required)")
    print(f"   • 2 tables created: banks and reviews")
    print(f"   • Database: bank_reviews")
else:
    print(f" WARNING: Only {total_reviews} reviews inserted (400 required)")

print("\n Task 3 Complete!")
print("Database ready for analysis.")
# Out:
# REQUIREMENTS CHECK
# SUCCESS: All requirements met!
#    • Reviews inserted: 1200 (≥400 required)
#    • 2 tables created: banks and reviews
#    • Database: bank_reviews
#
#  Task 3 Complete!
# Database ready for analysis.
